# %%
#loading the necessary packages 
#Author: Burhanuddin Bhopalwala
import numpy as np
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings 
warnings.filterwarnings("ignore")
sns.set_style("darkgrid") # possible values: dark, darkgrid, white, whitegrid, ticks

# %%
#loading the data 
covid19_df = pd.read_csv("dataset/latestdata.csv")

# %%
#look at the data and cleaning it

covid19_df.head()
# Out:
#        ID    age   sex              city          province        country  \
# 0  000-1-    NaN   NaN               NaN  Pays de la Loire         France
# 1  000-1-  50-59  male  Snohomish County        Washington  United States
# 2  000-1-    NaN   NaN               NaN               NaN            NaN
# 3  000-1-    NaN   NaN               NaN               NaN            NaN
# 4  000-1-    NaN   NaN               NaN               NaN            NaN
#
#    wuhan(0)_not_wuhan(1)  latitude  longitude geo_resolution  ...  \
# 0                    1.0  47.48646   -0.81128         admin1  ...
# 1                    1.0  48.04818 -121.69600         admin2  ...
# 2                    NaN       NaN        NaN            NaN  ...
# 3                    NaN       NaN        NaN            NaN  ...
# 4                    NaN       NaN        NaN            NaN  ...
#
#   date_death_or_discharge notes_for_discussion location admin3  \
# 0                     NaN                  NaN      NaN    NaN
# 1                     NaN                  NaN      NaN    NaN
# 2                     NaN                  NaN      NaN    NaN
# 3                     NaN                  NaN      NaN    NaN
# 4                     NaN                  NaN      NaN    NaN
#
#              admin2            admin1    country_new admin_id  \
# 0               NaN  Pays de la Loire         France       12
# 1  Snohomish County        Washington  United States     2988
# 2               NaN               NaN            NaN      NaN
# 3               NaN               NaN            NaN      NaN
# 4               NaN               NaN            NaN      NaN
#
#   data_moderator_initials travel_history_binary
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
#
# [5 rows x 34 columns]

# %%
import pdb
import time
import math
import random
import warnings
from tqdm import tqdm
from prettytable import PrettyTable

random.seed(50)
warnings.filterwarnings("ignore")

# %%
covid_data[covid_data['age'].notnull()].count()
# Out:
# ID                          4210
# age                         4210
# sex                         3739
# city                        3590
# province                    3899
# country                     4189
# wuhan(0)_not_wuhan(1)       3807
# latitude                    3836
# longitude                   3836
# geo_resolution              3836
# date_onset_symptoms         1060
# date_admission_hospital      922
# date_confirmation           4161
# symptoms                     751
# lives_in_Wuhan               916
# travel_history_dates         672
# travel_history_location     1594
# reported_market_exposure     449
# additional_information      1708
# chronic_disease_binary       316
# chronic_disease               41
# source                      3648
# sequence_available           461
# outcome                      282
# date_death_or_discharge      190
# notes_for_discussion          36
# location                     684
# admin3                       295
# admin2                      1803
# admin1                      2678
# country_new                 2833
# admin_id                    2914
# data_moderator_initials       50
# travel_history_binary        154
# dtype: int64

# %%
#split the data into test train and validation data set

# %%
#make a model

# %%
#get the accuracy

# %%
#plot the accuracy

# %%
#work with the validation set and validate your model

# %%
#test the model with the test data

# %%
#input of new data and predictions

# %%
#implement the model and get your propability of an infection
